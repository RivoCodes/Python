# %%
import pandas as pd
import os

# %%
pwd=os.getcwd()

# %%
df = pd.read_csv(pwd + "/Amazon_Drivers_Rating.csv")
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# ...

# %%
columns_to_drop = ['Delivery_person_ID', 'Restaurant_latitude', 
                   'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude','Order_Date',
                   'Time_Orderd','Time_Order_picked','Type_of_order','multiple_deliveries','Festival','Name:']
columns_to_drop
# Out:
# ['Delivery_person_ID',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Type_of_order',
#  'multiple_deliveries',
#  'Festival',
#  'Name:']

# %%
dataset_modified = df.drop(columns=columns_to_drop)
dataset_modified
# Out:
#            ID  Delivery_person_Age  Delivery_person_Ratings     Weather  \
# 0      0x2318                  NaN                      NaN         NaN
# 1      0x3474                 28.0                      4.6       Windy
# 2      0x9420                 23.0                      4.5      Stormy
# 3      0x72ee                 21.0                      4.8         Fog
# 4      0xa759                 31.0                      4.6       Sunny
# ...       ...                  ...                      ...         ...
# 11394  0x6909                 35.0                      4.6       Sunny
# 11395  0x443b                 33.0                      4.9  Sandstorms
# 11396  0x1ea5                  NaN                      NaN         NaN
# 11397  0x22d4                 27.0                      4.7  Sandstorms
# 11398  0xb7be                 39.0                      5.0       Windy
#
#       Road_traffic_density  Vehicle_condition   Type_of_vehicle           City
# ...

# %%
dataset_dropna=dataset_modified.dropna()
dataset_dropna
# Out:
#            ID  Delivery_person_Age  Delivery_person_Ratings     Weather  \
# 1      0x3474                 28.0                      4.6       Windy
# 2      0x9420                 23.0                      4.5      Stormy
# 3      0x72ee                 21.0                      4.8         Fog
# 4      0xa759                 31.0                      4.6       Sunny
# 5      0xc4af                 26.0                      4.7         Fog
# ...       ...                  ...                      ...         ...
# 11393  0xe240                 31.0                      4.7       Windy
# 11394  0x6909                 35.0                      4.6       Sunny
# 11395  0x443b                 33.0                      4.9  Sandstorms
# 11397  0x22d4                 27.0                      4.7  Sandstorms
# 11398  0xb7be                 39.0                      5.0       Windy
#
#       Road_traffic_density  Vehicle_condition Type_of_vehicle           City
# ...

# %%
dataset_dropna.to_excel(pwd + "/Amazon_Ratings_Clean.xlsx", index=False)
