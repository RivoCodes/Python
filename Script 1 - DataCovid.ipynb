# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_csv(pwd + "/owid-covid-data (1).csv")
dataset
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 236843      ZWE    Africa     Zimbabwe  2022-11-18     257893.0        0.0
# 236844      ZWE    Africa     Zimbabwe  2022-11-19     257893.0        0.0
# 236845      ZWE    Africa     Zimbabwe  2022-11-20     257893.0        0.0
# 236846      ZWE    Africa     Zimbabwe  2022-11-21     257893.0        0.0
# 236847      ZWE    Africa     Zimbabwe  2022-11-22     257893.0        0.0
#
# ...

# %%
dataset.head(100)
# Out:
#    iso_code continent     location        date  total_cases  new_cases  \
# 0       AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1       AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2       AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3       AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4       AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ..      ...       ...          ...         ...          ...        ...
# 95      AFG      Asia  Afghanistan  2020-05-29      13745.0      643.0
# 96      AFG      Asia  Afghanistan  2020-05-30      14529.0      784.0
# 97      AFG      Asia  Afghanistan  2020-05-31      15180.0      651.0
# 98      AFG      Asia  Afghanistan  2020-06-01      15836.0      656.0
# 99      AFG      Asia  Afghanistan  2020-06-02      16578.0      742.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
dataset.tail(100)
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 236748      ZWE    Africa  Zimbabwe  2022-08-15     256544.0        5.0
# 236749      ZWE    Africa  Zimbabwe  2022-08-16     256561.0       17.0
# 236750      ZWE    Africa  Zimbabwe  2022-08-17     256565.0        4.0
# 236751      ZWE    Africa  Zimbabwe  2022-08-18     256579.0       14.0
# 236752      ZWE    Africa  Zimbabwe  2022-08-19     256596.0       17.0
# ...         ...       ...       ...         ...          ...        ...
# 236843      ZWE    Africa  Zimbabwe  2022-11-18     257893.0        0.0
# 236844      ZWE    Africa  Zimbabwe  2022-11-19     257893.0        0.0
# 236845      ZWE    Africa  Zimbabwe  2022-11-20     257893.0        0.0
# 236846      ZWE    Africa  Zimbabwe  2022-11-21     257893.0        0.0
# 236847      ZWE    Africa  Zimbabwe  2022-11-22     257893.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
dataset_new = dataset[['location','total_cases']]
dataset_new
# Out:
#            location  total_cases
# 0       Afghanistan          5.0
# 1       Afghanistan          5.0
# 2       Afghanistan          5.0
# 3       Afghanistan          5.0
# 4       Afghanistan          5.0
# ...             ...          ...
# 236843     Zimbabwe     257893.0
# 236844     Zimbabwe     257893.0
# 236845     Zimbabwe     257893.0
# 236846     Zimbabwe     257893.0
# 236847     Zimbabwe     257893.0
#
# [236848 rows x 2 columns]

# %%
dataset_new['location'].value_counts().Afghanistan
# Out:
# 1003

# %%
dataset_new['location'].value_counts().Zimbabwe
# Out:
# 978

# %%
data1 = [{'Afganistan': 1003, 'Zimbabwe': 978}]
data1
# Out:
# [{'Afganistan': 1003, 'Zimbabwe': 978}]

# %%
dataset_afghanistan = dataset_new[dataset_new['location'] == 'Afghanistan']
dataset_afghanistan
# Out:
#          location  total_cases
# 0     Afghanistan          5.0
# 1     Afghanistan          5.0
# 2     Afghanistan          5.0
# 3     Afghanistan          5.0
# 4     Afghanistan          5.0
# ...           ...          ...
# 998   Afghanistan     205009.0
# 999   Afghanistan     205039.0
# 1000  Afghanistan     205146.0
# 1001  Afghanistan     205229.0
# 1002  Afghanistan     205324.0
#
# [1003 rows x 2 columns]

# %%
TotalCases_Afghanistan = dataset_afghanistan['total_cases'].sum()
print(TotalCases_Afghanistan)
# Out:
# 107745159.0

# %%
AVGCases_Afghanistan = dataset_afghanistan['total_cases'].mean()
print(AVGCases_Afghanistan)
# Out:
# 107422.89032901297

# %%
import numpy as np

# %%
Penjumlahan_Afghanistan = ['107745159']
Penjumlahan_Afghanistan
# Out:
# ['107745159']

# %%
dataset_afghanistan1 = dataset_afghanistan.insert(0,tuple (['Penjumlahan_Afghanistan']))
dataset_afghanistan1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [94], line 1
# ----> 1 dataset_afghanistan1 = dataset_afghanistan.insert(0,tuple (['Penjumlahan_Afghanistan']))
#       2 dataset_afghanistan1
#
# TypeError: DataFrame.insert() missing 1 required positional argument: 'value'

# %%
dataset_merged_one = pd.merge(left=TotalCases_Afghanistan, right=AVGCases_Afghanistan, how="left", left_on=["Question + Subquestion", "Answer"], right_on=["Question + Subquestion", "Answer"])
dataset_merged_three["Same Answer"].fillna(0, inplace=True)

# %%
dataset_Zimbabwe = dataset_new[dataset_new['location'] == 'Zimbabwe']
dataset_Zimbabwe
# Out:
#         location  total_cases
# 235870  Zimbabwe          1.0
# 235871  Zimbabwe          3.0
# 235872  Zimbabwe          3.0
# 235873  Zimbabwe          3.0
# 235874  Zimbabwe          3.0
# ...          ...          ...
# 236843  Zimbabwe     257893.0
# 236844  Zimbabwe     257893.0
# 236845  Zimbabwe     257893.0
# 236846  Zimbabwe     257893.0
# 236847  Zimbabwe     257893.0
#
# [978 rows x 2 columns]

# %%
TotalCases_Zimbabwe = dataset_Zimbabwe['total_cases'].sum()
print(TotalCases_Zimbabwe)
# Out:
# 112453653.0

# %%
MeanCases_Zimbabwe = dataset_Zimbabwe['total_cases'].mean()
print(MeanCases_Zimbabwe)
# Out:
# 114983.28527607361
